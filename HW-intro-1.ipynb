# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
# url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv"
# url = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/postprocessor.csv"
# url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv"
# url="https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv"
url="https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv"
df = pd.read_csv(url)
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
print("Records count:", len(df))

print("Shape:", df.shape[0])
# Out:
# Records count: 10000
# Shape: 10000

# %%
print(df.columns)

fuel_count = df['fuel_type'].nunique()

print("Number of fuel types:", fuel_count)
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='object')
# Number of fuel types: 3

# %%
missing_count = df.isnull().any().sum()
print("missing values:", missing_count)

print("Missing values per column:")
print(df.isnull().sum())
# Out:
# missing values: 2
# Missing values per column:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
df['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
#calculate the median before imputation
median_before = df['horsepower'].median()
print("Median before imputation:", median_before)

#calculate the median after imputation
mean_value = df['horsepower'].mean()
median_after = df['horsepower'].fillna(mean_value).median()
print("Median after imputation:", median_after)


print("Did the median change?", "Yes" if median_before != median_after else "No")
# Out:
# Median before imputation: 254.0
# Median after imputation: 254.44601556505535
# Did the median change? Yes

# %%
asia_cars = df[df['origin'] == 'Asia']

selected_df = asia_cars[['vehicle_weight', 'model_year']]

first_7 = selected_df.head(7)

X = first_7.values

XTX = X.T @ X

XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = (XTX_inv @ X.T) @ y

w_sum = w.sum()

print("Weights vector (w):", w)
print("Sum of weights:", w_sum)
# Out:
# Weights vector (w): [0.13644777 0.2327492 ]
# Sum of weights: 0.36919696904925486
